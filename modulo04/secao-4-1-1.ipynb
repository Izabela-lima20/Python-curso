# %% [markdown]
# ### 4.1.1 funções
# ![image.png](attachment:image.png)

# %%
# minha primeira fução
def nome_funcao():
    print("Minha função executando algo")
# chamando minha função
nome_funcao()
# Out:
# Minha função executando algo
