# %% [markdown]
# ### Tomada de decisão
# ### operação relacionadas
# ### operação de igualdade ( == ) ou verdadeiro ou falso (False / True)
# ### atribuição (=)

# %% [markdown]
# ### o operador de igualdade (==)

# %%
print(1 == 2)
print(1 == 1)
print(1 == 1.0)
print(2 == 0b10) # banary 2
# Out:
# False
# True
# True
# True

# %% [markdown]
# ### o operador de desigualdade (!=)

# %%
print(1 != 2)
print(1 != 1)
print(1 != 1.0)
# Out:
# True
# False
# False

# %% [markdown]
# ### Operadores de comparação: maior que (>)
# ### Operadores de comparação: maior ou igual a ( >= )

# %%
print( 1 > 2)
print(2 > 1)
print(2 >= 1)
print(2 >= 0b10)
# Out:
# False
# True
# True
# True

# %% [markdown]
# ### Comparação de operadores: menor que é menor ou igual que

# %%
print( 1 < 2)
print(2 < 1)
print(2 <= 1)
print(2 <= 0b10)
# Out:
# True
# False
# False
# True

# %% [markdown]
# ### Atualizando a lista de prioridade de operadores
# | seq | operador | descição|
# | - | - | :-: |
# | 1 | ** | Exponenciação|
# | 2 | +,- | Unario sinal|
# | 3 | *,/,//,%| Multiplicação, divisaõ e resto|
# | 4 |  +,- | Soma e subtração|
# | 5 | >, >=, <,<=| Maior, maior igual, menor, menor igual|
# | 6 | ==, !| igualdade , diferença|

# %% [markdown]
# ### Condições e execução condicional
# ### operador if (se)
# -sintaxe:
# if condição_verdade:
#    comando_a_ser_executado1()
#    comando_a_ser_executado2()

# %%
idade = int(input("Digite sua idade:"))
if idade >= 18:
    print("Voce é maior de idade")
    print("voce pode dirigir, se habilitado!")
print("fim do programa")
# Out:
# fim do programa

# %% [markdown]
# ### Execução condicional: o comando if-else

# %%
idade = int(input("Digite sua idade"))
if idade >=18:
      print("Voce é maior de idade")
      print("voce pode dirigir, se habilitado!")
else: 
       print("Voce é menor de idade")
       print("voce não pode dirigir!")
       print("fim do programa")
# Out:
# Voce é maior de idade
# voce pode dirigir, se habilitado!

# %% [markdown]
# ### if encadeado

# %%
idade = int(input("Digite sua idade"))
if idade >=18:
      print("Voce é maior de idade")
      print("voce pode dirigir, se habilitado!")
      if idade >=70:
             print("voce deve fazer exame medicos anuais")
      else:
             if idade >=60:
              print("deve fazer exames a cada dois anos")   
else: 
       print("Voce é menor de idade")
       print("voce não pode dirigir!")
       print("fim do programa")
# Out:
# Voce é maior de idade
# voce pode dirigir, se habilitado!
# deve fazer exames a cada dois anos

# %% [markdown]
# ### O comando elif e um complemeto do if

# %%
idade = int(input("Digite sua idade"))
if idade >=70:
        print("Voce é maior de idade")
        print("voce pode dirigir, se habilitado!")
        print("voce deve fazer exame medicos anuais")

elif idade >= 65:
       print("Voce é maior de idade")
       print("voce pode dirigir, se habilitado!")
       print("deve fazer exames a cada dois anos") 

elif idade >=18:
      print("Voce é maior de idade")
      print("voce pode dirigir, se habilitado!")

else: 
       print("Voce é menor de idade")
       print("voce não pode dirigir!")
       print("fim do programa")
# Out:
# Voce é menor de idade
# voce não pode dirigir!
# fim do programa

# %%
# obtendo do maior numero entre dois numeros 
num1 = int(input("Digite o primeiro numero:"))
num2 = int(input("Digite o segundo numero:"))
maior = num1
if num2 > maior:
    maior = num2
    print("O maior numero é:", maior)
# Out:
# O maior numero é: 2

# %%
# obtendo do maior numero entre tres numeros 
num1 = int(input("Digite o primeiro numero:"))
num2 = int(input("Digite o segundo numero:"))
num3 = int(input("Digite o terceiro numero:"))

maior = num1
if num2 > maior:
    maior = num2

if num3 > maior:
    maior = num3    

    print("O maior numero é:", maior)
# Out:
# O maior numero é: 9

# %%
#uso do if com strings
nome = input ("Digite seu nome: ")
nome2 = input ("Digite outro nome: ")
if nome > nome2:
    print(nome, "é maior que" , nome2)
else:
    print(nome2, "é maior que ou igual a", nome)
# Out:
# 031 é maior que ou igual a 030

# %% [markdown]
# ### 3.1.10   LAB   Operadores de comparação e execução condicional
# ![image.png](attachment:image.png)

# %%
#Resolução

name = input("Insira o nome da planta: ") # Pede ao usuário para inserir o nome de uma flor e armazena esse nome na variável 'name'.

if name == "Spathiphyllum": # Verifica se o valor de 'name' é exatamente igual a "Spathiphyllum".
    print("Sim - Spathiphyllum é a melhor planta de todos os tempos!") # Se a condição for verdadeira, esta mensagem será exibida.

elif name == "spathiphyllum": # Verifica se o valor de 'name' é exatamente igual a "spathiphyllum".
    print("Não, eu quero uma grande Spathiphyllum!") # Se a condição for verdadeira, esta mensagem será exibida.

else:  # CASO NENHUMA DAS CONDIÇÕES ANTERIA SEJA VERDADEIRAS, o código dentro do 'else' será executado.
    print("Spathiphyllum! Não", name + "!")# Exibe uma mensagem, com o nome inserido pelo usuário concatenado.
# Out:
# Spathiphyllum! Não Spathiphyllumm!

# %% [markdown]
# ### 3.1.11   LAB   Essenciais da declaração if-else
# ![image.png](attachment:image.png)

# %%
income = float(input("Entre com os rendimentos anuais ")) #Aqui, o código pede ao usuário para informar o valor dos seus rendimentos anuais. Esse valor é convertido para um número do tipo float, para garantir que ele possa ser um número decimal, e é armazenado na variável income.

if income < 85528:#Aqui temos uma estrutura condicional if-else, que calcula o imposto de acordo com a faixa de rendimento:
 
 tax = income * 0.18 - 556.02

else:
 tax = 14839.02 + (income - 85528) * 0.32
# Se a renda for menor que 85.528 (primeira faixa de imposto): o imposto é calculado multiplicando os rendimentos por 18% (0.18) e subtraindo 556,02.
#Se a renda for maior ou igual a 85.528 (segunda faixa de imposto): o imposto fixo para essa faixa é de 14.839,02, e o valor que exceder os 85.528 é tributado a 32% (0.32).

# Se o imposto for negativo, ele deve ser zero.
if tax < 0: #Essa parte garante que, caso o cálculo do imposto resulte em um valor negativo, o imposto será ajustado para 0.
    tax = 0 #A função round(tax, 0) arredonda o valor do imposto para o número inteiro mais próximo, sem casas decimais. Isso é feito para simplificar o valor do imposto, já que ele deve ser pago em unidades inteiras de "thalers".

# Arredonda o imposto para o inteiro mais próximo.
tax = round(tax, 0)

print("A taxa é:", int(tax), "thalers") #mprime o valor do imposto arredondado, mostrando a mensagem "A taxa é: X thalers", onde "X" é o valor do imposto, já convertido para um número inteiro.
# Out:
# A taxa é: 14839 thalers

# %% [markdown]
# ### 3.1.12   LAB   Essenciais da declaração if-elif-else
# ![image.png](attachment:image.png)

# %%
#A função input() pega o que o usuário digitar, mas o que ele digitar é tratado como texto, então usamos int() para transformar esse texto em número. Agora o código vai trabalhar com o ano que você digitou.
ano = int(input("Digite um ano: ")) # aqui criei a variavel ano, O código pede para você digitar um ano, por exemplo, 2025.

if ano < 1582: #Ele vai ver se o ano é menor que 1582, porque antes dessa data a gente usava outro tipo de calendário, então o código diz:
 print("Esse ano não está dentro do período do calendário gregoriano")
else:
   if ano  % 4 != 0: #Primeiro, ele vê se o ano não é divisível por 4 (não dá para dividir o ano por 4 sem restar nada). Se não for, é um ano comum:
     print("ano comum")

   elif ano % 100 != 0: #Se o ano for divisível por 4, o programa vai ver se ele não é divisível por 100. Se não for, o ano é bissexto:
     print("Ano bissexto/ Leap year")

   elif ano % 400 != 0: #Mas, se o ano for divisível por 100, o programa vai checar se ele também é divisível por 400. Se for, ele é bissexto, se não for, é comum:
     print("ano comum")

   else:
     print("Ano bissexto")#Se o ano for divisível por 400, ele é bissexto:

     # ! = (não igual)
     # % e resto, ou seja ele divite o ano por 4 e vai ter um resto 
     # if ano  % 4 != 0: se o ano não for divisive por 4 ele e comun 
     # se o ano termina com 00 ele e divisivel por 100
# Out:
# ano comum

# %% [markdown]
# ### 3.1.13 RESUMO DA SEÇÃO
# ![image.png](attachment:image.png)

# %%
### Multipla atribuição...
a, b, c = 1,2,3
# valores de a = 5 , b = 6 , faça uma permuta de com as variaveis

a = 5
b = 6 
#efetuando a troca

apoio = a
a = b
b = apoio

#efetuando a permuta no python
a, b = b, a
